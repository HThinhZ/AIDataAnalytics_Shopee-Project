# %% [markdown]
# ## **Task 3: Preprocessing data**
# (Edit from Quan_Luu_Preprocessing_data branch)
# <hr/>

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ### *1. Read raw data from mongoDB Local*

# %%
# Step 1: Read raw data
# Read data from MongoDB and save it in a list
# Read 50000 data from MongoDB and save it in a dataframe
def read_raw_data(collection, x, y):
    data_list = []
    total_documents = y - x
    with tqdm(total=total_documents, desc='Getting Documents') as pbar:
        for document in collection.find({"crawl_id": {"$gte": x, "$lt": y}}):
            del document['_id']
            data_list.append(document)
            pbar.update(1)    

    df = pd.DataFrame(data_list)
    return df

# %% [markdown]
# ### *2. Drop unused columns*

# %% [markdown]
# #### 2.1. Drop unused columns

# %%
# Step 2: Drop unused columns
def drop_unused_columns(df):
       # List of fixed columns to keep
       used_columns = ['itemid', 'shopid', 'name', 'stock', 'sold', 'historical_sold',
              'liked_count', 'cmt_count', 'item_status', 'price', 'price_min',
              'price_max', 'price_min_before_discount', 'price_max_before_discount',
              'price_before_discount', 'tier_variations', 'item_rating',
              'show_free_shipping', 'shop_location', 'is_on_flash_sale', 'shop_name',
              'shop_rating', 'global_sold_count', 'flash_sale_stock', 'crawl_time',
              'crawl_id'] 

       unused_columns = [col for col in df.columns if col not in used_columns]

       # Dropping columns that are not in the fixed list
       df = df.drop(columns=unused_columns)

       return df

# %% [markdown]
# #### 2.2. Column Information
# Mô tả các cột dữ liệu và các kiểu dữ liệu mong muốn
#
# |STT| Tên cột    | Mô tả| Kiểu dữ liệu mong muốn |
# |---|:-----------:|:-------------:|:---|
# |1| itemid| Id của sản phẩm| String|
# |2| shopid| ID của shop| string|
# |3| stock| Số lượng sản phẩm trong kho| int |
# |4| sold| Số lượng sản phẩm đã bán| int|
# |5| liked_count| Số lượt thích sản phẩm| int|
# |6| cmt_count| Số lượt bình luận| int|
# |7| item_status| trạng thái sản phẩm| bool|
# |8| price| giá sản phẩm| float|
# |9| price_min|giá tối thiểu| float|
# |10| price_max| giá tối đa| float|
# |11| price_min_before_discount| giá tối thiểu trước discount| float|
# |12| price_max_before_discount| giá tối đa trước discount| float|
# |13| price_before_discount| giá trước discount| string|
# |14| tier_variations| kích thước, màu sắc và các đặc tính khác của sản phẩm| dict|
# |15| item_rating| các đánh giá của sản phẩm(bao gồm đánh giá trung bình và số đánh giá của từng sao)| dict|
# |16| show_free_shipping| shop có free ship hay không| bool|
# |17| shop_location|vị trí của shop| string|
# |18| is_on_flash_sale| sản phẩm có đang sale hay không| bool|
# |19| shop_name| tên shop| string|
# |20| shop_rating| đánh giá của shop| float|
# |21| global_sold_count| số lượng sản phẩm được bán trên thế giới trên shoppe| int|
# |22| flash_sale_stock| số lượng sản phẩm còn lại trong đợt flash sale| string|
# |23| crawl_time| thời điểm crawl data| date time|
# |24| historical _sold| Số lượng đã bán trong quá khứ| int|
# |25| name| tên sản phẩm| string|

# %% [markdown]
# ### *3. Edit data columns*
# Có nhiều cột có kiểu dữ liệu không hợp lý nên chuyển chúng về kiểu dữ liệu phù hợp với việc phân tích

# %% [markdown]
# #### 3.1. Edit Price
# các cột giá cả bị lớn hơn 100000 lần

# %%
# Step 3: Edit data columns
## Step 3.1: Edit price
def edit_price(df):
    price_columns = ['price','price_min','price_max','price_min_before_discount','price_max_before_discount','price_before_discount']
    df[price_columns]=df[price_columns]/100000
    return df

# %% [markdown]
# #### 3.2. Convert data type

# %%
## Step 3.2: Convert data type
def convert_data_type(df):
    int_columns = ['stock','sold','historical_sold','liked_count','cmt_count','global_sold_count','flash_sale_stock','crawl_id']
    df['itemid']=df['itemid'].astype('str')
    df['shopid']=df['shopid'].astype('str')
    df[int_columns]=df[int_columns].astype('int32')
    return df

# %% [markdown]
# #### 3.3. Edit some object columns

# %% [markdown]
# ##### 3.3.1. Tier variations columns

# %%
## Step 3.3: Edit some object columns
# hàm lấy ra màu
colors = ["ĐỎ","VÀNG","TRẮNG","ĐEN","HỒNG","TÍM","CAM","NÂU","XÁM","LAM",'GHI','XANH','BE','THAN','RÊU','CHÌ','NGẪU','TIÊU']

def is_color(list_color:str):
    list_return = []
    #item = item.split('.')[0]
    for item in list_color:
        item=item.replace(',',' ')
        item=item.replace('XDƯƠNG','XANH')
        item=item.replace('XANHĐÁ-Mũ','XANH')
        split_item = item.split(' ')
        for color in split_item:
            if '-' in color:
                color.replace(" ","")
                a = color.split('-')
                for cl in a:
                    if cl.upper() in colors:
                        list_return.append(cl)
            else:
                if color.upper() in colors:
                    list_return.append(color)
        if len(list_return) == 0:
            return 'NGẪU NHIÊN'
        return list_return
    
def get_options_size(columns):
    if len(columns) > 1:
        return columns[1]['options']
    return ['No size']

def get_options_color(columns):
        return columns[0]['options']

def explore_color(array):
    if type(array) == list:
        return ", ".join(array)
    else:
        return array

### Step 3.3.1 : Edit tier variations columns
def edit_tier_variations_columns(df):
    # color
    df['color']=df['tier_variations'].apply(get_options_color)
    df['color']=df['color'].apply(is_color)
    df['color']=df['color'].apply(explore_color)
    # size
    df['size']=df['tier_variations'].apply(get_options_size)
    # drop tier_variations columns
    df.drop('tier_variations',axis=1,inplace=True)
    return df

# %% [markdown]
# ##### 3.3.2. Item rating columns

# %%
### Step 3.3.2: Edit item rating columns
# lấy rating
def get_rating_star(item):
    return item['rating_star']
def get_rating_count(item):
    return item['rating_count']
def get_rcount_with_image(item):
    return item['rcount_with_image']
def get_rcount_with_context(item):
    return item['rcount_with_context']

def edit_item_rating_columns(df):
    # init new column
    df['rating_star'] = df['item_rating'].apply(get_rating_star)
    df['rating_count'] = df['item_rating'].apply(get_rating_count)
    df['rcount_with_image'] = df['item_rating'].apply(get_rcount_with_image)
    df['rcount_with_context'] = df['item_rating'].apply(get_rcount_with_context)
    return df

# %% [markdown]
# ### *4. Pipeline for preprocessing data*

# %%
def preprocessing_pipeline(collection, x, num_documents):
    y = x + 20000
    if y > num_documents:
        y = num_documents
    
    # Step 1: Read raw data
    df = read_raw_data(collection, x, y)
    # Step 2: Drop unused columns
    df = drop_unused_columns(df)
    # Step 3: Edit data columns
    ## Step 3.1: Edit price
    df = edit_price(df)
    ## Step 3.2: Convert data type
    df = convert_data_type(df)
    ## Step 3.3: Edit some object columns
    ### Step 3.3.1 : Edit tier variations columns
    df = edit_tier_variations_columns(df)
    ### Step 3.3.2: Edit item rating columns
    df = edit_item_rating_columns(df)

    return df

# %% [markdown]
# ### *5. Store preprocessing data*

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client['Task2_Database']
collection = db['Shopee_Full_Data']

# Count the number of documents in the collection
num_documents_local = collection.count_documents({}) 
print("Number of documents in the collection:", num_documents_local)
# Out:
# Number of documents in the collection: 441322

# %%
client_p = MongoClient('mongodb://localhost:27017/')
db_p = client_p ['Task2_Database']
collection_p = db_p['Shopee_Full_Preprocessing_Data']
num_documents_server = collection_p.count_documents({})
print("Number of documents in the collection:", num_documents_server)
# Out:
# Number of documents in the collection: 441322

# %%
df = preprocessing_pipeline(collection, num_documents_server, num_documents_local)

dict_df = df.to_dict('records')
result = collection_p.insert_many(dict_df)
print ('=> Inserted document IDs successfuly:', result.inserted_ids)

password = "qthls2023"
uri = "mongodb+srv://shopee_database_1:{}@cluster0.1wsiirv.mongodb.net/?retryWrites=true&w=majority".format(password)
client_server = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client_server.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

db_server = client_server['Task2_Database']
collection_server = db_server['Shopee_Full_Preprocessing_Data']
dict_df = df.to_dict('records')
result = collection_server.insert_many(dict_df)
print ('=> Inserted document IDs successfuly:', result.inserted_ids)
# Out:
# Getting Documents: 100%|██████████| 8270/8270 [00:14<00:00, 568.40it/s]
# => Inserted document IDs successfuly: [ObjectId('656614e5e010dfc9ecb63c36'), ObjectId('656614e5e010dfc9ecb63c37'), ObjectId('656614e5e010dfc9ecb63c38'), ObjectId('656614e5e010dfc9ecb63c39'), ObjectId('656614e5e010dfc9ecb63c3a'), ObjectId('656614e5e010dfc9ecb63c3b'), ObjectId('656614e5e010dfc9ecb63c3c'), ObjectId('656614e5e010dfc9ecb63c3d'), ObjectId('656614e5e010dfc9ecb63c3e'), ObjectId('656614e5e010dfc9ecb63c3f'), ObjectId('656614e5e010dfc9ecb63c40'), ObjectId('656614e5e010dfc9ecb63c41'), ObjectId('656614e5e010dfc9ecb63c42'), ObjectId('656614e5e010dfc9ecb63c43'), ObjectId('656614e5e010dfc9ecb63c44'), ObjectId('656614e5e010dfc9ecb63c45'), ObjectId('656614e5e010dfc9ecb63c46'), ObjectId('656614e5e010dfc9ecb63c47'), ObjectId('656614e5e010dfc9ecb63c48'), ObjectId('656614e5e010dfc9ecb63c49'), ObjectId('656614e5e010dfc9ecb63c4a'), ObjectId('656614e5e010dfc9ecb63c4b'), ObjectId('656614e5e010dfc9ecb63c4c'), ObjectId('656614e5e010dfc9ecb63c4d'), ObjectId('656614e5e010dfc9ecb63c4e'), ObjectId('656614e5e010dfc9ecb63c4f'), ObjectId('656614e5e010dfc9ecb63c50'), ObjectId('656614e5e010dfc9ecb63c51'), ObjectId('656614e5e010dfc9ecb63c52'), ObjectId('656614e5e010dfc9ecb63c53'), ObjectId('656614e5e010dfc9ecb63c54'), ObjectId('656614e5e010dfc9ecb63c55'), ObjectId('656614e5e010dfc9ecb63c56'), ObjectId('656614e5e010dfc9ecb63c57'), ObjectId('656614e5e010dfc9ecb63c58'), ObjectId('656614e5e010dfc9ecb63c59'), ObjectId('656614e5e010dfc9ecb63c5a'), ObjectId('656614e5e010dfc9ecb63c5b'), ObjectId('656614e5e010dfc9ecb63c5c'), ObjectId('656614e5e010dfc9ecb63c5d'), ObjectId('656614e5e010dfc9ecb63c5e'), ObjectId('656614e5e010dfc9ecb63c5f'), ObjectId('656614e5e010dfc9ecb63c60'), ObjectId('656614e5e010dfc9ecb63c61'), ObjectId('656614e5e010dfc9ecb63c62'), ObjectId('656614e5e010dfc9ecb63c63'), ObjectId('656614e5e010dfc9ecb63c64'), ObjectId('656614e5e010dfc9ecb63c65'), ObjectId('656614e5e010dfc9ecb63c66'), ObjectId('656614e5e010dfc9ecb63c67'), ObjectId('656614e5e010dfc9ecb63c68'), ObjectId('656614e5e010dfc9ecb63c69'), ObjectId('656614e5e010dfc9ecb63c6a'), ObjectId('656614e5e010dfc9ecb63c6b'), ObjectId('656614e5e010dfc9ecb63c6c'), ObjectId('656614e5e010dfc9ecb63c6d'), ObjectId('656614e5e010dfc9ecb63c6e'), ObjectId('656614e5e010dfc9ecb63c6f'), ObjectId('656614e5e010dfc9ecb63c70'), ObjectId('656614e5e010dfc9ecb63c71'), ObjectId('656614e5e010dfc9ecb63c72'), ObjectId('656614e5e010dfc9ecb63c73'), ObjectId('656614e5e010dfc9ecb63c74'), ObjectId('656614e5e010dfc9ecb63c75'), ObjectId('656614e5e010dfc9ecb63c76'), ObjectId('656614e5e010dfc9ecb63c77'), ObjectId('656614e5e010dfc9ecb63c78'), ObjectId('656614e5e010dfc9ecb63c79'), ObjectId('656614e5e010dfc9ecb63c7a'), ObjectId('656614e5e010dfc9ecb63c7b'), ObjectId('656614e5e010dfc9ecb63c7c'), ObjectId('656614e5e010dfc9ecb63c7d'), ObjectId('656614e5e010dfc9ecb63c7e'), ObjectId('656614e5e010dfc9ecb63c7f'), ObjectId('656614e5e010dfc9ecb63c80'), ObjectId('656614e5e010dfc9ecb63c81'), ObjectId('656614e5e010dfc9ecb63c82'), ObjectId('656614e5e010dfc9ecb63c83'), ObjectId('656614e5e010dfc9ecb63c84'), ObjectId('656614e5e010dfc9ecb63c85'), ObjectId('656614e5e010dfc9ecb63c86'), ObjectId('656614e5e010dfc9ecb63c87'), ObjectId('656614e5e010dfc9ecb63c88'), ObjectId('656614e5e010dfc9ecb63c89'), ObjectId('656614e5e010dfc9ecb63c8a'), ObjectId('656614e5e010dfc9ecb63c8b'), ObjectId('656614e5e010dfc9ecb63c8c'), ObjectId('656614e5e010dfc9ecb63c8d'), ObjectId('656614e5e010dfc9ecb63c8e'), ObjectId('656614e5e010dfc9ecb63c8f'), ObjectId('656614e5e010dfc9ecb63c90'), ObjectId('656614e5e010dfc9ecb63c91'), ObjectId('656614e5e010dfc9ecb63c92'), ObjectId('656614e5e010dfc9ecb63c93'), ObjectId('656614e5e010dfc9ecb63c94'), ObjectId('656614e5e010dfc9ecb63c95'), ObjectId('656614e5e010dfc9ecb63c96'), ObjectId('656614e5e010dfc9ecb63c97'), ObjectId('656614e5e010dfc9ecb63c98'), ObjectId('656614e5e010dfc9ecb63c99'), ObjectId('656614e5e010dfc9ecb63c9a'), ObjectId('656614e5e010dfc9ecb63c9b'), ObjectId('656614e5e010dfc9ecb63c9c'), ObjectId('656614e5e010dfc9ecb63c9d'), ObjectId( ...
# Pinged your deployment. You successfully connected to MongoDB!
# => Inserted document IDs successfuly: [ObjectId('656614ece010dfc9ecb65c85'), ObjectId('656614ece010dfc9ecb65c86'), ObjectId('656614ece010dfc9ecb65c87'), ObjectId('656614ece010dfc9ecb65c88'), ObjectId('656614ece010dfc9ecb65c89'), ObjectId('656614ece010dfc9ecb65c8a'), ObjectId('656614ece010dfc9ecb65c8b'), ObjectId('656614ece010dfc9ecb65c8c'), ObjectId('656614ece010dfc9ecb65c8d'), ObjectId('656614ece010dfc9ecb65c8e'), ObjectId('656614ece010dfc9ecb65c8f'), ObjectId('656614ece010dfc9ecb65c90'), ObjectId('656614ece010dfc9ecb65c91'), ObjectId('656614ece010dfc9ecb65c92'), ObjectId('656614ece010dfc9ecb65c93'), ObjectId('656614ece010dfc9ecb65c94'), ObjectId('656614ece010dfc9ecb65c95'), ObjectId('656614ece010dfc9ecb65c96'), ObjectId('656614ece010dfc9ecb65c97'), ObjectId('656614ece010dfc9ecb65c98'), ObjectId('656614ece010dfc9ecb65c99'), ObjectId('656614ece010dfc9ecb65c9a'), ObjectId('656614ece010dfc9ecb65c9b'), ObjectId('656614ece010dfc9ecb65c9c'), ObjectId('656614ece010dfc9ecb65c9d'), ObjectId('656614ece010dfc9ecb65c9e'), ObjectId('656614ece010dfc9ecb65c9f'), ObjectId('656614ece010dfc9ecb65ca0'), ObjectId('656614ece010dfc9ecb65ca1'), ObjectId('656614ece010dfc9ecb65ca2'), ObjectId('656614ece010dfc9ecb65ca3'), ObjectId('656614ece010dfc9ecb65ca4'), ObjectId('656614ece010dfc9ecb65ca5'), ObjectId('656614ece010dfc9ecb65ca6'), ObjectId('656614ece010dfc9ecb65ca7'), ObjectId('656614ece010dfc9ecb65ca8'), ObjectId('656614ece010dfc9ecb65ca9'), ObjectId('656614ece010dfc9ecb65caa'), ObjectId('656614ece010dfc9ecb65cab'), ObjectId('656614ece010dfc9ecb65cac'), ObjectId('656614ece010dfc9ecb65cad'), ObjectId('656614ece010dfc9ecb65cae'), ObjectId('656614ece010dfc9ecb65caf'), ObjectId('656614ece010dfc9ecb65cb0'), ObjectId('656614ece010dfc9ecb65cb1'), ObjectId('656614ece010dfc9ecb65cb2'), ObjectId('656614ece010dfc9ecb65cb3'), ObjectId('656614ece010dfc9ecb65cb4'), ObjectId('656614ece010dfc9ecb65cb5'), ObjectId('656614ece010dfc9ecb65cb6'), ObjectId('656614ece010dfc9ecb65cb7'), ObjectId('656614ece010dfc9ecb65cb8'), ObjectId('656614ece010dfc9ecb65cb9'), ObjectId('656614ece010dfc9ecb65cba'), ObjectId('656614ece010dfc9ecb65cbb'), ObjectId('656614ece010dfc9ecb65cbc'), ObjectId('656614ece010dfc9ecb65cbd'), ObjectId('656614ece010dfc9ecb65cbe'), ObjectId('656614ece010dfc9ecb65cbf'), ObjectId('656614ece010dfc9ecb65cc0'), ObjectId('656614ece010dfc9ecb65cc1'), ObjectId('656614ece010dfc9ecb65cc2'), ObjectId('656614ece010dfc9ecb65cc3'), ObjectId('656614ece010dfc9ecb65cc4'), ObjectId('656614ece010dfc9ecb65cc5'), ObjectId('656614ece010dfc9ecb65cc6'), ObjectId('656614ece010dfc9ecb65cc7'), ObjectId('656614ece010dfc9ecb65cc8'), ObjectId('656614ece010dfc9ecb65cc9'), ObjectId('656614ece010dfc9ecb65cca'), ObjectId('656614ece010dfc9ecb65ccb'), ObjectId('656614ece010dfc9ecb65ccc'), ObjectId('656614ece010dfc9ecb65ccd'), ObjectId('656614ece010dfc9ecb65cce'), ObjectId('656614ece010dfc9ecb65ccf'), ObjectId('656614ece010dfc9ecb65cd0'), ObjectId('656614ece010dfc9ecb65cd1'), ObjectId('656614ece010dfc9ecb65cd2'), ObjectId('656614ece010dfc9ecb65cd3'), ObjectId('656614ece010dfc9ecb65cd4'), ObjectId('656614ece010dfc9ecb65cd5'), ObjectId('656614ece010dfc9ecb65cd6'), ObjectId('656614ece010dfc9ecb65cd7'), ObjectId('656614ece010dfc9ecb65cd8'), ObjectId('656614ece010dfc9ecb65cd9'), ObjectId('656614ece010dfc9ecb65cda'), ObjectId('656614ece010dfc9ecb65cdb'), ObjectId('656614ece010dfc9ecb65cdc'), ObjectId('656614ece010dfc9ecb65cdd'), ObjectId('656614ece010dfc9ecb65cde'), ObjectId('656614ece010dfc9ecb65cdf'), ObjectId('656614ece010dfc9ecb65ce0'), ObjectId('656614ece010dfc9ecb65ce1'), ObjectId('656614ece010dfc9ecb65ce2'), ObjectId('656614ece010dfc9ecb65ce3'), ObjectId('656614ece010dfc9ecb65ce4'), ObjectId('656614ece010dfc9ecb65ce5'), ObjectId('656614ece010dfc9ecb65ce6'), ObjectId('656614ece010dfc9ecb65ce7'), ObjectId('656614ece010dfc9ecb65ce8'), ObjectId('656614ece010dfc9ecb65ce9'), ObjectId('656614ece010dfc9ecb65cea'), ObjectId('656614ece010dfc9ecb65ceb'), ObjectId('656614ece010dfc9ecb65cec'), ObjectId( ...
