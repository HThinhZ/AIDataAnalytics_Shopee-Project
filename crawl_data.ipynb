kYTpK9w7Cr6uxP5Nssuspc1k1S3ujX1Aqk4DDH3dUTVQDxz%2BAzcK%2F1NXA1JtT%2F3IGb%2FgLGGo%3D%7CrAFZgwLX4FcvaifZ%7C08%7C3; ds=a9a5b478ccd474ac9548865fc193a497; _ga=GA1.1.1101825207.1694085109; _dc_gtm_UA-61914164-6=1; _ga_M32T05RVZT=GS1.1.1696149807.14.1.1696150524.17.0.0; SPC_EC=MTRuNWxpZzNqVm9nM0NOOIK5gZ6rHfw8nDbOJ+b5hGCaHq8b1YsO8SbvjDAC2i6AYQ0/qInwzbwDqc93RbCYbl0XrY5HWrtmmTpoiOKDqQW5BdLzEmuq+8wSdQPfl2I1HekcCKxH4tyRzBmWtnCm7/vJJWxiqQMX0Kw6FwHie9Y7/sqBCCKkV2eWJatEuae8',
    'Referer': 'https://shopee.vn/mall/Th%E1%BB%9Di-Trang-Nam-cat.11035567',
    'Sec-Ch-Ua': '"Microsoft Edge";v="117", "Not;A=Brand";v="8", "Chromium";v="117"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': "Windows",
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)\
          Chrome/117.0.0.0 Safari/537.36 Edg/117.0.2045.43'
}

# %%
top_shopee_mall_name = []
top_shopee_mall_name_url = 'https://shopee.vn/api/v4/official_shop/get_shops?category_id=11035567&limit=20&offset=0'
request = requests.get(top_shopee_mall_name_url,json = payload)
if request.status_code == 200:
        for raw_data in request.json().get('data').get('official_shops'):
            top_shopee_mall_name.append(raw_data['username'])

top_shopee_mall_name
# Out:
# ['sp.btw2',
#  'poloman.vn',
#  'tsla.store',
#  'coolmate.vn',
#  '5s_official',
#  'rough.vn',
#  'patternvn',
#  'levents.vn',
#  'guzado.vn',
#  'thoitrangmando',
#  'tsimple_official',
#  'owen.fashion',
#  'thoitrangbiluxury',
#  'feaer_store',
#  'sukiyafashion.vn',
#  '4menstores',
#  'haidang.fashion',
#  'thoitrangnam4u',
#  'thoitrangeverest',
#  'kojibavn']

# %% [markdown]
# #### **2. Get some basic information about all shops above**

# %%
headers_2 = {
    'Accept': 'application/json',
    'Accept-Language': 'en-US,en;q=0.9',
    'Content-Type': 'application/json',
    'Sec-Ch-Ua': '"Microsoft Edge";v="117", "Not;A=Brand";v="8", "Chromium";v="117"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': "Windows",
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)\
          Chrome/117.0.0.0 Safari/537.36 Edg/117.0.2045.43'
}

# %%
# result = []
# for i in tqdm(range(0, len(top_shopee_mall_name))):
#     username = top_shopee_mall_name[i]
#     shopee_mall_link = 'https://shopee.vn/api/v4/shop/get_shop_base?entry_point=&need_cancel_rate=true&request_source=shop_home_page&username=' + \
#         username + '&version=1'
#     request = requests.get(shopee_mall_link,headers= headers_2)
#     print('Request page {} success!!!'.format(i+1)) 
#     raw_data = request.json().get('data')
#     result.append(raw_data)
# result
# Out:
#   5%|▌         | 1/20 [00:00<00:03,  4.80it/s]
# Request page 1 success!!!
#  15%|█▌        | 3/20 [00:00<00:03,  5.03it/s]
# Request page 2 success!!!
# Request page 3 success!!!
#  20%|██        | 4/20 [00:00<00:03,  5.30it/s]
# Request page 4 success!!!
# Request page 5 success!!!
#  35%|███▌      | 7/20 [00:01<00:02,  5.40it/s]
# Request page 6 success!!!
# Request page 7 success!!!
#  45%|████▌     | 9/20 [00:01<00:02,  5.46it/s]
# Request page 8 success!!!
# Request page 9 success!!!
#  55%|█████▌    | 11/20 [00:02<00:01,  5.49it/s]
# Request page 10 success!!!
# Request page 11 success!!!
#  65%|██████▌   | 13/20 [00:02<00:01,  5.16it/s]
# Request page 12 success!!!
# Request page 13 success!!!
#  75%|███████▌  | 15/20 [00:02<00:01,  4.74it/s]
# Request page 14 success!!!
# Request page 15 success!!!
#  85%|████████▌ | 17/20 [00:03<00:00,  4.95it/s]
# Request page 16 success!!!
# Request page 17 success!!!
#  95%|█████████▌| 19/20 [00:03<00:00,  5.27it/s]
# Request page 18 success!!!
# Request page 19 success!!!
# 100%|██████████| 20/20 [00:03<00:00,  5.16it/s]
# Request page 20 success!!!
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  {'shopid': 92937520,
#   'userid': 92938999,
#   'name': 'Thời trang nam Owen',
#   'cover': '2a37e1134905b88f53376cdb430607c6',
#   'follower_count': 127248,
#   'show_official_shop_label': True,
#   'is_preferred_plus_seller': False,
#   'is_shopee_verified': False,
#   'chat_disabled': True,
#   'rating_star': 4.891277,
#   'has_decoration': True,
#   'account': {'username': 'owen.fashion',
#    'following_count': 23,
#    'portrait': '57342653dc9b639f5848dc52c99d94b0',
#    'is_seller': True,
#    'phone_verified': True,
#    'email_verified': False,
#    'fbid': '',
#    'total_avg_star': 4.891277,
#    'hide_likes': 0,
#    'feed_account_info': {'is_kol': False, 'can_post_feed': True},
#    'status': 1},
#   'last_active_time': 1696060769,
#   'vacation': False,
#   'followed': False,
#   'ab_test_info': {'header_tabs_layout': 'control',
#    'deep_discount_item_card': 'default',
#    'item_card': 'control',
#    'feeds_live_landing': 'treatment',
#    'image_category': 'new_image_cat',
#    'remove_item_count_on_category_tab': 'default',
#    'default_component_improvement': 'top_products',
#    'deep_discount_enhancement': 'default',
#    'new_default_scp': 'treatment_2',
#    'default_landing': 'control',
#    'two_tier_category': 'default',
#    'two_tier_category_for_layoutc': 'default',
#    'live_stream_auto_play': 'treatment',
#    'dd_item_card_2': 'control',
#    'tier_shop_category': 'treatment_new_layout',
#    'product_one_per_row': 'control',
#    'fashion_shop_improvement': 'control',
#    'shop_rfy_entrypoint': 'treatment',
#    'voucher_popup_non_buyers': 'control',
#    'category_ui_improvement_1': 'new_category_ui',
#    'autoplay_highlight_video': 'default',
#    'ads_shop_improvement': 'control',
#    'non_deco_shop_homepage_personalization': 'treatment_1',
#    'brand_day_overlap': 'control',
#    'truncate_shop_item_card': 'control'},
#   'description': 'Owen là thương hiệu thời trang dành cho nam giới của Công ty cổ phần Thời trang Kowil Việt Nam\nOwen mang phong cách hiện đại vào những trang phục dòng thời trang trung và cao cấp vốn bị cho là khá mô phạm, chuẩn mực chỉ phù hợp với dân công sở. Sự phong phú về kiểu dáng, màu sắc, hoa văn, chất liệu cùng cách pha phối tinh tế và sự đầu tư kỹ lưỡng về mọi mặt khiến mỗi sản phẩm của hãng đều là một tác phẩm nghệ thuật, tôn vinh vẻ nam tính và mang lại cảm giác thành đạt',
#   'item_count': 2172,
#   'response_rate': 65,
#   'show_video_entry': False,
#   'video_entry_info': '',
#   'campaign_hot_deal_discount_min': 10,
#   'show_deco_entry': False,
#   'shop_rating': {'rating_normal': 415,
#    'rating_bad': 228,
#    'rating_good': 24196},
#   'seller_metrics': {'cancellation_visibility': 0, 'cancellation_warning': 10},
#   'response_time': 10961,
#   'ctime': 1538021574,
#   'show_tab': {'new_arrival_tab': {'show_new_arrival_items': True,
#     'new_arrival_items_start_ts': 1693584000,
#     'latest_item_ctime': 1695976121},
#    'show_live_tab': False,
#    'membership_tab': {'show_membership_tab': False,
#     'has_join_membership': False},
#    'show_flash_sale_tab': False},
#   'toggles': {'disable_chat_performance': False},
#   'shop_tab_meta': {'shop_is_non_deco': False},
#   'block_cb_user': False,
#   'video_rn_jump_url': '',
#   'user_browse_shop_time': 30,
#   'background_color': '',
#   'highlight_color': '',
#   'brand_day_end_time': 0},
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
headers = {
    'Accept': 'application/json',
    'Accept-Language': 'en-US,en;q=0.9',
    # 'Af-Ac-Enc-Dat': '...',
    'Af-Ac-Enc-Sz-Token': 'uRKw9a+zYIi3wlgBlywMxw==|QkzkYTpK9w7Cr6uxP5Nssuspc1k1S3ujX1Aqk0iUG3dUTVQDxz+AzcK/1NXA1JtT/3IGb/gLGGo=|rAFZgwLX4FcvaifZ|08|3',
    'Content-Type': 'application/json',
    'Cookie': 'SPC_F=rDW5Nh6DF1E9pc5zd1KLjyUH3Pb9wEsE; REC_T_ID=b4f17b94-3e46-11ee-8366-347379167cc4; _gcl_au=1.1.1023688809.1692418391; _med=refer; SPC_CLIENTID=ckRXNU5oNkRGMUU5upjceygpajxlufhk; _hjSessionUser_868286=eyJpZCI6IjUxZWYyZDE1LWEzYWUtNWYwZC1hODNmLWQyMTY4Yjc2OWNkOSIsImNyZWF0ZWQiOjE2OTUxNDA0Mjg4MTMsImV4aXN0aW5nIjp0cnVlfQ==; SPC_ST=.UGE1Z3ExT2F0ZWhwZ2MyehcVr24uuUKm3pHMFnp5Q8BS+ujYk7cGXhHlgxY8J9sJzSqwjh+Y2y01blsOSGzCQfDImQDKNzQnuljrL/mm5/Z/vaWDpwO9UXwBtOjD4obdBUYYcMpP3sh69ZFtjrAu92zT9yovhDTKmudYRncLRzVXzgzYhTNGJC0jh2gILJAOGIdkm2A7unB7ymjMmMSRSA==; SPC_U=1078039954; SPC_T_IV=cUdZcDFoaVNMbElqVUxoU

    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)\
          Chrome/117.0.0.0 Safari/537.36 Edg/117.0.2045.43',
}
shopee_mall = []
shopee_mall_url = 'https://shopee.vn/api/v4/shop/get_shop_base?entry_point=&need_cancel_rate=true&request_source=shop_home_page&username=sp.btw2&version=1'
request = requests.get(shopee_mall_url,headers=headers)
request.content
# if request.status_code == 200:
#         for raw_data in request.json():
#             shopee_mall.append(raw_data)

# shopee_mall
import json

json_data = json.loads(request.content)

# %%
json_data['data']
# Out:
# {'shopid': 40342563,
#  'userid': 40343949,
#  'name': 'Aviano Menswear',
#  'cover': 'e03048a5576062894717bb1ab92241f2',
#  'follower_count': 1198213,
#  'show_official_shop_label': True,
#  'is_preferred_plus_seller': False,
#  'is_shopee_verified': False,
#  'chat_disabled': True,
#  'rating_star': 4.854938,
#  'has_decoration': True,
#  'account': {'username': 'sp.btw2',
#   'following_count': 858,
#   'portrait': '9439d537460fba30c1c9703e200099d5',
#   'is_seller': True,
#   'phone_verified': True,
#   'email_verified': True,
#   'fbid': '',
#   'total_avg_star': 4.854954,
#   'hide_likes': 0,
#   'feed_account_info': {'is_kol': False, 'can_post_feed': True},
#   'status': 1},
#  'last_active_time': 1696161663,
#  'vacation': False,
#  'followed': False,
#  'real_url_if_matching_custom_url': '',
#  'ab_test_info': {'header_tabs_layout': 'control',
#   'deep_discount_item_card': 'default',
#   'item_card': 'control',
#   'feeds_live_landing': 'treatment',
#   'image_category': 'new_image_cat',
#   'remove_item_count_on_category_tab': 'default',
#   'default_component_improvement': 'top_products',
#   'deep_discount_enhancement': 'default',
#   'new_default_scp': 'treatment_2',
#   'default_landing': 'control',
#   'two_tier_category': 'default',
#   'two_tier_category_for_layoutc': 'default',
#   'live_stream_auto_play': 'treatment',
#   'dd_item_card_2': 'control',
#   'tier_shop_category': 'treatment_new_layout',
#   'product_one_per_row': 'control',
#   'fashion_shop_improvement': 'control',
#   'shop_rfy_entrypoint': 'treatment',
#   'voucher_popup_non_buyers': 'control',
#   'category_ui_improvement_1': 'new_category_ui',
#   'autoplay_highlight_video': 'default',
#   'ads_shop_improvement': 'control',
#   'non_deco_shop_homepage_personalization': 'treatment_1',
#   'brand_day_overlap': 'treatment_1',
#   'truncate_shop_item_card': 'control'},
#  'description': '',
#  'item_count': 232,
#  'response_rate': 100,
#  'show_video_entry': False,
#  'video_entry_info': '',
#  'campaign_hot_deal_discount_min': 10,
#  'show_deco_entry': False,
#  'shop_rating': {'rating_normal': 11241,
#   'rating_bad': 4824,
#   'rating_good': 419279},
#  'buyer_rating': {'rating_count': [0, 0, 0, 0, 0, 47], 'rating_star': 5},
#  'seller_metrics': {'cancellation_visibility': 0,
#   'cancellation_warning': 10,
#   'cancellation_rate': 0},
#  'response_time': 5228,
#  'ctime': 1508990028,
#  'show_tab': {'new_arrival_tab': {'show_new_arrival_items': True,
#    'new_arrival_items_start_ts': 1693584000,
#    'latest_item_ctime': 1695874824},
#   'show_live_tab': True,
#   'membership_tab': {'show_membership_tab': True,
#    'has_join_membership': False},
#   'show_flash_sale_tab': True},
#  'toggles': {'disable_chat_performance': False},
#  'shop_tab_meta': {'shop_is_non_deco': False,
#   'shop_without_op_behavior': False},
#  'block_cb_user': False,
#  'video_rn_jump_url': '',
#  'user_browse_shop_time': 30,
#  'background_color': '',
#  'highlight_color': '',
#  'brand_day_end_time': 0}

# %%
import subprocess
import json

def curl_request(url):
    command = ['curl', url]
    result = subprocess.run(command, capture_output=True, text=True)
    
    if result.returncode == 0:
        return result.stdout
    else:
        print(f"Error: {result.stderr}")
        return None

# Example usage
url = 'https://shopee.vn/api/v4/shop/get_shop_base?entry_point=&need_cancel_rate=true&request_source=shop_home_page&username=sp.btw2&version=1'
response = curl_request(url)
if response:
    data = json.loads(response)
    # Process the data as needed
    print(data)
# Out:
# {'is_customized': False, 'is_login': False, 'platform': 0, 'action_type': 2, 'error': 90309999, 'tracking_id': 'aec42c4c-083f-4a29-ab76-d53b91aa66fb', 'report_extra_info': ''}

# %%
headers = {
    'Accept': 'application/json',
    'Accept-Language': 'en-US,en;q=0.9',
    'Content-Type': 'application/json',
    'Sec-Ch-Ua': '"Microsoft Edge";v="117", "Not;A=Brand";v="8", "Chromium";v="117"',
    # 'Af-Ac-Enc-Dat': '...',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': "Windows",
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)\
          Chrome/117.0.0.0 Safari/537.36 Edg/117.0.2045.43',
}
item = []
item_url = 'https://shopee.vn/api/v4/shop/search_items?filter_sold_out=1&limit=30&offset=0&order=desc&shopid=40342563&sort_by=pop&use_case=4'
request = requests.get(item_url,headers=headers)
print(request.content)
# Out:
# b'{"error":0,"error_msg":"","total_count":47,"nomore":false,"items":[{"itemid":6455243031,"shopid":40342563,"item_basic":{"itemid":6455243031,"shopid":40342563,"name":"B\xe1\xbb\x99 Th\xe1\xbb\x83 Thao Nam Th\xe1\xbb\x9di Trang Cao C\xe1\xba\xa5p Th\xc6\xb0\xc6\xa1ng Hi\xe1\xbb\x87u VICERO","label_ids":[1000262,1000258,1000259,1000260,1000263,1000255,1000256,1000254,1000257,1000264,1000265,1000266,1000267,1000270,1000269,1000272,1000271,1000274,1000275,1000278,1000276,1000279,1000908,1000927,1000268,1000273,1000277,1000984,1001035,1006487,1006856,1008793,1009763,1012191,1014184,1014267,700066389,700085243,700066398,1133882,1115185,700066642,700085482,1400066702,1400095073,700085579,1213576,1213632,1243613,700150015,700155008,1208670,1278591,1278592,1268596,1268599,1263605,1278629,700185064,700190078,700195073,700190079,1400170039,1400175056,1400170062,1278696,1263701,1268699,1428581,1428593,1433638,1428664,1428679,1428689,700305069,1428733,1400290091,1428749,1428753,1523584,1508583,1428713,298418372,58,1001044,700085289,1115060,1400066583,1400066667,1400085417,1134090,1400095029,844931086908638,825249635454464,1583596,1518589,700400001,997736025,1717907933,298458308,298468369,298463385,1638619,1643609,997781004,997771054,700440006,700450002,700450019,700445041,298413316,700485088,298488450,1009063,1688739,1688758,